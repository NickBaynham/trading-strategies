# %%
investors=["Scott Steele", "Dan Pfeiffer", "Larry Liss"]

for person in investors:
    print("There's an investor called " + person)
# Out:
# There's an investor called Scott Steele
# There's an investor called Dan Pfeiffer
# There's an investor called Larry Liss

# %%
stocks = {
    "CAKE": "Cheesecake Factory",
    "PZZA": "Pappa John's Pizza",
    "FUN": "Cedar Fair",
    "CAR": "Avis Budget Group"
}

for ticker, name in stocks.items():
    print(ticker + ": " + stocks[ticker])
# Out:
# CAKE: Cheesecake Factory
# PZZA: Pappa John's Pizza
# FUN: Cedar Fair
# CAR: Avis Budget Group

# %%
# %matplotlib inline
import pandas as pd
data = pd.read_csv('SNPS.csv', index_col='trade_date', parse_dates=['trade_date'])
data['SMA']=data['open'].rolling(50).mean()
data.plot()
